# %%
# This notebook extracts LLhs from fit files for the 1D distributions
# Note that due to some small historical ugliness we have two formats here.
#   arising because Amp0 was re-run more elegantly later.

# %%
import numpy as np 
import glob
import os
import re

# %%
def RunIt(outpath, params):
    outfile = open(outpath, "w")
    count=0
    PrintEvery=100
    fit_dirs = []
    for param in params:    
        fit_dirs = glob.glob(rootdir + "fit." + str(param) +'*')
        print("Searching for files: " + rootdir + "fit." + str(param) +'*')
        if not fit_dirs :
            print("WARNING: No Fit Directories Found For " + str(param) + " In " + str(rootdir) )
            continue
        else:
            print("Found "  + str(len(fit_dirs)) + " Fit Directories....")

 
        print("Writing Output to: "  + str(outfile))

        for fit_dir in fit_dirs:
            try:
                fit_file = open(str(fit_dir) + "/out",'r')
            except:
                print("WARNING: " + str(fit_dir) + "/out Does Not Exist!" )
            else:
                try:
                  #  lines=fit_file.readlines()[2]
                    lines= fit_file.readlines()
#                    llh_string = re.findall("LLH=\d+\.\d+", lines[2])
                    for line in lines:
                        if 'LLH' in line:
                            LLH=re.findall("LLH=\d+\.\d+", line)[0][4:]
                            DT=line.split("=")[2][0:-3]

                except:
                    print("WARNING: " + str(fit_file) + " Is Empty!" )
                else:
                    try:
                        shift = float(re.findall(r".\dp\d\d\d", str(fit_dir))[0].replace("p", "."))
                    except:
                        try:
                            shift = float(re.findall(r".\dp\d\d", str(fit_dir))[0].replace("p", "."))
                        except:
                            try:
                                shift = float(re.findall(r".\dp\d", str(fit_dir))[0].replace("p", "."))
                            except:
                                if "_0.dat" in str(fit_dir):
                                    shift = 0
                                else:
                                    print("WARNING: Unable to resolve shift. Setting shift to nan.")
                                    shift = float('NaN')

                    dom = fit_dir.rsplit('dat-', 1)[1]
                    
                    fit_file.close()
                    outfile.write(param.split("_")[0]+ " " + param.split("_")[1]+ " " +str(shift) + " " + str(LLH) + " " + str(dom) +" "  + str(DT)+ "\n")


                    count=count+1
                    if(count%PrintEvery==0):
                        print("Absorbed "+str(count) + " LLHs")
                   # print(str(shift) + " " + str(llh) + " " + str(dom))
    outfile.close()


    print("Done!")

# %%
rootdir = '/data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/'
phsparams=[]
for i in range(1,10):
    phsparams.append("Phs_"+str(i))
print phsparams
phsoutpath="/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt"
# Out:
# ['Phs_1', 'Phs_2', 'Phs_3', 'Phs_4', 'Phs_5', 'Phs_6', 'Phs_7', 'Phs_8', 'Phs_9']

# %%
RunIt(phsoutpath,phsparams)
# Out:
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_1*
# Found 4425 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt', mode 'w' at 0x7f94dc9bcf60>
# Absorbed 100 LLHs
# Absorbed 200 LLHs
# Absorbed 300 LLHs
# Absorbed 400 LLHs
# Absorbed 500 LLHs
# Absorbed 600 LLHs
# Absorbed 700 LLHs
# Absorbed 800 LLHs
# Absorbed 900 LLHs
# Absorbed 1000 LLHs
# Absorbed 1100 LLHs
# Absorbed 1200 LLHs
# Absorbed 1300 LLHs
# Absorbed 1400 LLHs
# Absorbed 1500 LLHs
# Absorbed 1600 LLHs
# Absorbed 1700 LLHs
# Absorbed 1800 LLHs
# Absorbed 1900 LLHs
# Absorbed 2000 LLHs
# Absorbed 2100 LLHs
# Absorbed 2200 LLHs
# Absorbed 2300 LLHs
# Absorbed 2400 LLHs
# Absorbed 2500 LLHs
# Absorbed 2600 LLHs
# Absorbed 2700 LLHs
# Absorbed 2800 LLHs
# Absorbed 2900 LLHs
# Absorbed 3000 LLHs
# Absorbed 3100 LLHs
# Absorbed 3200 LLHs
# Absorbed 3300 LLHs
# Absorbed 3400 LLHs
# Absorbed 3500 LLHs
# Absorbed 3600 LLHs
# Absorbed 3700 LLHs
# Absorbed 3800 LLHs
# Absorbed 3900 LLHs
# Absorbed 4000 LLHs
# Absorbed 4100 LLHs
# Absorbed 4200 LLHs
# Absorbed 4300 LLHs
# Absorbed 4400 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_2*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt', mode 'w' at 0x7f94dc9bcf60>
# Absorbed 4500 LLHs
# Absorbed 4600 LLHs
# Absorbed 4700 LLHs
# Absorbed 4800 LLHs
# Absorbed 4900 LLHs
# Absorbed 5000 LLHs
# Absorbed 5100 LLHs
# Absorbed 5200 LLHs
# Absorbed 5300 LLHs
# Absorbed 5400 LLHs
# Absorbed 5500 LLHs
# Absorbed 5600 LLHs
# Absorbed 5700 LLHs
# Absorbed 5800 LLHs
# Absorbed 5900 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_3*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt', mode 'w' at 0x7f94dc9bcf60>
# Absorbed 6000 LLHs
# Absorbed 6100 LLHs
# Absorbed 6200 LLHs
# Absorbed 6300 LLHs
# Absorbed 6400 LLHs
# Absorbed 6500 LLHs
# Absorbed 6600 LLHs
# Absorbed 6700 LLHs
# Absorbed 6800 LLHs
# Absorbed 6900 LLHs
# Absorbed 7000 LLHs
# Absorbed 7100 LLHs
# Absorbed 7200 LLHs
# Absorbed 7300 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_4*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt', mode 'w' at 0x7f94dc9bcf60>
# Absorbed 7400 LLHs
# Absorbed 7500 LLHs
# Absorbed 7600 LLHs
# Absorbed 7700 LLHs
# Absorbed 7800 LLHs
# Absorbed 7900 LLHs
# Absorbed 8000 LLHs
# Absorbed 8100 LLHs
# Absorbed 8200 LLHs
# Absorbed 8300 LLHs
# Absorbed 8400 LLHs
# Absorbed 8500 LLHs
# Absorbed 8600 LLHs
# Absorbed 8700 LLHs
# Absorbed 8800 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_5*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt', mode 'w' at 0x7f94dc9bcf60>
# Absorbed 8900 LLHs
# Absorbed 9000 LLHs
# Absorbed 9100 LLHs
# Absorbed 9200 LLHs
# Absorbed 9300 LLHs
# Absorbed 9400 LLHs
# Absorbed 9500 LLHs
# Absorbed 9600 LLHs
# Absorbed 9700 LLHs
# Absorbed 9800 LLHs
# Absorbed 9900 LLHs
# Absorbed 10000 LLHs
# Absorbed 10100 LLHs
# Absorbed 10200 LLHs
# Absorbed 10300 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_6*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt', mode 'w' at 0x7f94dc9bcf60>
# Absorbed 10400 LLHs
# Absorbed 10500 LLHs
# Absorbed 10600 LLHs
# Absorbed 10700 LLHs
# Absorbed 10800 LLHs
# Absorbed 10900 LLHs
# Absorbed 11000 LLHs
# Absorbed 11100 LLHs
# WARNING: <open file '/data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_6+0p583.dat-8/out', mode 'r' at 0x7f94dc9a2f60> Is Empty!
# Absorbed 11200 LLHs
# Absorbed 11300 LLHs
# Absorbed 11400 LLHs
# Absorbed 11500 LLHs
# Absorbed 11600 LLHs
# Absorbed 11700 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_7*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt', mode 'w' at 0x7f94dc9bcf60>
# Absorbed 11800 LLHs
# Absorbed 11900 LLHs
# Absorbed 12000 LLHs
# Absorbed 12100 LLHs
# Absorbed 12200 LLHs
# Absorbed 12300 LLHs
# Absorbed 12400 LLHs
# Absorbed 12500 LLHs
# Absorbed 12600 LLHs
# Absorbed 12700 LLHs
# Absorbed 12800 LLHs
# Absorbed 12900 LLHs
# Absorbed 13000 LLHs
# Absorbed 13100 LLHs
# Absorbed 13200 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_8*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt', mode 'w' at 0x7f94dc9bcf60>
# Absorbed 13300 LLHs
# Absorbed 13400 LLHs
# Absorbed 13500 LLHs
# Absorbed 13600 LLHs
# Absorbed 13700 LLHs
# Absorbed 13800 LLHs
# Absorbed 13900 LLHs
# Absorbed 14000 LLHs
# Absorbed 14100 LLHs
# Absorbed 14200 LLHs
# Absorbed 14300 LLHs
# Absorbed 14400 LLHs
# Absorbed 14500 LLHs
# Absorbed 14600 LLHs
# Absorbed 14700 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Phs/fit.Phs_9*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Phs.txt', mode 'w' at 0x7f94dc9bcf60>
# Absorbed 14800 LLHs
# Absorbed 14900 LLHs
# Absorbed 15000 LLHs
# Absorbed 15100 LLHs
# Absorbed 15200 LLHs
# Absorbed 15300 LLHs
# Absorbed 15400 LLHs
# Absorbed 15500 LLHs
# Absorbed 15600 LLHs
# Absorbed 15700 LLHs
# Absorbed 15800 LLHs
# Absorbed 15900 LLHs
# Absorbed 16000 LLHs
# Absorbed 16100 LLHs
# Absorbed 16200 LLHs
# Done!

# %%
rootdir = '/data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/'
ampparams=[]
for i in range(1,10):
    ampparams.append("Amp_"+str(i))
print ampparams
ampoutpath="/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt"
# Out:
# ['Amp_1', 'Amp_2', 'Amp_3', 'Amp_4', 'Amp_5', 'Amp_6', 'Amp_7', 'Amp_8', 'Amp_9']

# %%
RunIt(ampoutpath,ampparams)
# Out:
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/fit.Amp_1*
# Found 4425 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt', mode 'w' at 0x7f94dc9a2f60>
# Absorbed 100 LLHs
# Absorbed 200 LLHs
# Absorbed 300 LLHs
# Absorbed 400 LLHs
# Absorbed 500 LLHs
# Absorbed 600 LLHs
# Absorbed 700 LLHs
# Absorbed 800 LLHs
# Absorbed 900 LLHs
# Absorbed 1000 LLHs
# Absorbed 1100 LLHs
# Absorbed 1200 LLHs
# Absorbed 1300 LLHs
# Absorbed 1400 LLHs
# Absorbed 1500 LLHs
# Absorbed 1600 LLHs
# Absorbed 1700 LLHs
# Absorbed 1800 LLHs
# Absorbed 1900 LLHs
# Absorbed 2000 LLHs
# Absorbed 2100 LLHs
# Absorbed 2200 LLHs
# Absorbed 2300 LLHs
# Absorbed 2400 LLHs
# Absorbed 2500 LLHs
# Absorbed 2600 LLHs
# Absorbed 2700 LLHs
# Absorbed 2800 LLHs
# Absorbed 2900 LLHs
# Absorbed 3000 LLHs
# Absorbed 3100 LLHs
# Absorbed 3200 LLHs
# Absorbed 3300 LLHs
# Absorbed 3400 LLHs
# Absorbed 3500 LLHs
# Absorbed 3600 LLHs
# Absorbed 3700 LLHs
# Absorbed 3800 LLHs
# Absorbed 3900 LLHs
# Absorbed 4000 LLHs
# Absorbed 4100 LLHs
# Absorbed 4200 LLHs
# Absorbed 4300 LLHs
# Absorbed 4400 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/fit.Amp_2*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt', mode 'w' at 0x7f94dc9a2f60>
# Absorbed 4500 LLHs
# Absorbed 4600 LLHs
# Absorbed 4700 LLHs
# Absorbed 4800 LLHs
# Absorbed 4900 LLHs
# Absorbed 5000 LLHs
# Absorbed 5100 LLHs
# Absorbed 5200 LLHs
# Absorbed 5300 LLHs
# Absorbed 5400 LLHs
# Absorbed 5500 LLHs
# Absorbed 5600 LLHs
# Absorbed 5700 LLHs
# Absorbed 5800 LLHs
# Absorbed 5900 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/fit.Amp_3*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt', mode 'w' at 0x7f94dc9a2f60>
# Absorbed 6000 LLHs
# Absorbed 6100 LLHs
# Absorbed 6200 LLHs
# Absorbed 6300 LLHs
# Absorbed 6400 LLHs
# Absorbed 6500 LLHs
# Absorbed 6600 LLHs
# Absorbed 6700 LLHs
# Absorbed 6800 LLHs
# Absorbed 6900 LLHs
# Absorbed 7000 LLHs
# Absorbed 7100 LLHs
# Absorbed 7200 LLHs
# Absorbed 7300 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/fit.Amp_4*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt', mode 'w' at 0x7f94dc9a2f60>
# Absorbed 7400 LLHs
# Absorbed 7500 LLHs
# Absorbed 7600 LLHs
# Absorbed 7700 LLHs
# Absorbed 7800 LLHs
# Absorbed 7900 LLHs
# Absorbed 8000 LLHs
# Absorbed 8100 LLHs
# Absorbed 8200 LLHs
# Absorbed 8300 LLHs
# Absorbed 8400 LLHs
# Absorbed 8500 LLHs
# Absorbed 8600 LLHs
# Absorbed 8700 LLHs
# Absorbed 8800 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/fit.Amp_5*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt', mode 'w' at 0x7f94dc9a2f60>
# Absorbed 8900 LLHs
# Absorbed 9000 LLHs
# Absorbed 9100 LLHs
# Absorbed 9200 LLHs
# Absorbed 9300 LLHs
# Absorbed 9400 LLHs
# Absorbed 9500 LLHs
# Absorbed 9600 LLHs
# Absorbed 9700 LLHs
# Absorbed 9800 LLHs
# Absorbed 9900 LLHs
# Absorbed 10000 LLHs
# Absorbed 10100 LLHs
# Absorbed 10200 LLHs
# Absorbed 10300 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/fit.Amp_6*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt', mode 'w' at 0x7f94dc9a2f60>
# Absorbed 10400 LLHs
# Absorbed 10500 LLHs
# Absorbed 10600 LLHs
# Absorbed 10700 LLHs
# Absorbed 10800 LLHs
# Absorbed 10900 LLHs
# Absorbed 11000 LLHs
# Absorbed 11100 LLHs
# Absorbed 11200 LLHs
# Absorbed 11300 LLHs
# Absorbed 11400 LLHs
# Absorbed 11500 LLHs
# Absorbed 11600 LLHs
# Absorbed 11700 LLHs
# Absorbed 11800 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/fit.Amp_7*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt', mode 'w' at 0x7f94dc9a2f60>
# Absorbed 11900 LLHs
# Absorbed 12000 LLHs
# Absorbed 12100 LLHs
# Absorbed 12200 LLHs
# Absorbed 12300 LLHs
# Absorbed 12400 LLHs
# Absorbed 12500 LLHs
# Absorbed 12600 LLHs
# Absorbed 12700 LLHs
# Absorbed 12800 LLHs
# Absorbed 12900 LLHs
# Absorbed 13000 LLHs
# Absorbed 13100 LLHs
# Absorbed 13200 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/fit.Amp_8*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt', mode 'w' at 0x7f94dc9a2f60>
# Absorbed 13300 LLHs
# Absorbed 13400 LLHs
# Absorbed 13500 LLHs
# Absorbed 13600 LLHs
# Absorbed 13700 LLHs
# Absorbed 13800 LLHs
# Absorbed 13900 LLHs
# Absorbed 14000 LLHs
# Absorbed 14100 LLHs
# Absorbed 14200 LLHs
# Absorbed 14300 LLHs
# Absorbed 14400 LLHs
# Absorbed 14500 LLHs
# Absorbed 14600 LLHs
# Absorbed 14700 LLHs
# Searching for files: /data/ana/NuFSGenMC/MultiSim/Fits/Fits/Amp/fit.Amp_9*
# Found 1475 Fit Directories....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt', mode 'w' at 0x7f94dc9a2f60>
# Absorbed 14800 LLHs
# Absorbed 14900 LLHs
# Absorbed 15000 LLHs
# Absorbed 15100 LLHs
# Absorbed 15200 LLHs
# Absorbed 15300 LLHs
# Absorbed 15400 LLHs
# Absorbed 15500 LLHs
# Absorbed 15600 LLHs
# Absorbed 15700 LLHs
# Absorbed 15800 LLHs
# Absorbed 15900 LLHs
# Absorbed 16000 LLHs
# Absorbed 16100 LLHs
# Absorbed 16200 LLHs
# Done!

# %%
def RunItNewFormat(rootdir, outpath):
    count=0
    PrintEvery=100
    fit_dirs = []
    fit_files = glob.glob(rootdir + "/out*")
    if not fit_files :
        print("WARNING: No Fit Directories Found In " + str(rootdir) )
        return
    else:
        print("Found "  + str(len(fit_files)) + " Fit Files....")


    outfile = open(outpath, "a")

    print("Writing Output to: "  + str(outfile))

    for fit_filen in fit_files:
        try:
            fit_file = open(str(fit_filen),'r')
        except:
            print("WARNING: " + str(fit_filen) + " Does Not Exist!" )
        else:
            try:
              #  lines=fit_file.readlines()[2]
                lines= fit_file.readlines()     
            except:
                print("WARNING: " + str(fit_filen) + " Is Empty!" )
                break
            HeaderLine=lines[2]
            Param=HeaderLine.split("_")[0]
            ParamNum=HeaderLine.split("_")[1].split("+")[0].split("-")[0]
         #   print HeaderLine
            try:
                shift = float(re.findall(r".\dp\d\d\d", str(HeaderLine))[0].replace("p", "."))
            except:
                try:
                    shift = float(re.findall(r".\dp\d\d", str(HeaderLine))[0].replace("p", "."))
                except:
                    try:
                        shift = float(re.findall(r".\dp\d", str(HeaderLine))[0].replace("p", "."))
                    except:
                        if "_0.dat" in str(HeaderLine):
                            shift = 0
                        else:
                            print("WARNING: Unable to resolve shift. Setting shift to nan.")
                            shift = float('NaN')
            

            for line in lines[3:-1]:
                if "DOM " in line:
                    if not "Bad" in line:
                     #   print line.split()
                        DOM=int(line.split()[1])
                        
                if 'LLH' in line:
                    LLH=re.findall("LLH=\d+\.\d+", line)[0][4:]
                    DT=line.split("=")[2][0:-3]
                    if(DOM!=3 and DOM!=1 and DOM!=21):
                        writeline=str(Param)+ " "+ str(ParamNum)+" " +str(shift) + " " + str(LLH) + " " + str(DOM) + " " + str(DT)
                #    print writeline
                #    print line
                        outfile.write(writeline + "\n")                    

                    count=count+1
                    if(count%PrintEvery==0):
                        print("Absorbed "+str(count) + " LLHs")
        fit_file.close()
    outfile.close()

    print("Done!")

# %%
RunItNewFormat("/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/ConstraintJobsOut/Amp0", "/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp0.txt")
# Out:
# Found 100 Fit Files....
# Writing Output to: <open file '/data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp0.txt', mode 'a' at 0x7f94dc9a2f60>
# Absorbed 100 LLHs
# Absorbed 200 LLHs
# Absorbed 300 LLHs
# Absorbed 400 LLHs
# Absorbed 500 LLHs
# Absorbed 600 LLHs
# Absorbed 700 LLHs
# Absorbed 800 LLHs
# Absorbed 900 LLHs
# Absorbed 1000 LLHs
# Absorbed 1100 LLHs
# Absorbed 1200 LLHs
# Absorbed 1300 LLHs
# Absorbed 1400 LLHs
# Done!

# %%
print ampoutpath
# Out:
# /data/ana/NuFSGenMC/MultiSim/MultisimOutputs/Constraints/LLHs/Amp.txt
